# %%
import pandas as pd
import re
import numpy as np
import math
from textblob import TextBlob
from nltk.sentiment import SentimentIntensityAnalyzer
import operator
from spellchecker import SpellChecker
import copy
from ast import literal_eval

# %% [markdown]
# ### Cleaning up the drugLib data

# %%
# Load data and combine train and test sets
drugLib_train = pd.read_csv("Data/drugLibTrain_raw.tsv", sep='\t')
drugLib_test = pd.read_csv("Data/drugLibTest_raw.tsv", sep='\t')
drugLib = pd.concat([drugLib_train, drugLib_test])

# %%
# Drop first column
drugLib = drugLib.drop(['Unnamed: 0'], axis=1)

# Assigning numerical values to effectiveness and sideEffects
# with a min score of 0 being ineffective or having no side effects 
# and a max score of 4 being highly effective or having extremely severe side effects.
drugLib['effectiveness'] = drugLib['effectiveness'].map({'Ineffective':0, 'Marginally Effective':1, 
                                                         'Moderately Effective':2, 'Considerably Effective':3,
                                                         'Highly Effective':4})

drugLib['sideEffects'] = drugLib['sideEffects'].map({'No Side Effects':0, 'Mild Side Effects':1, 
                                                         'Moderate Side Effects':2, 'Severe Side Effects':3,
                                                         'Extremely Severe Side Effects':4})

drugLib
# Out:
#            urlDrugName  rating  effectiveness  sideEffects  \
# 0            enalapril       4              4            1
# 1     ortho-tri-cyclen       1              4            3
# 2              ponstel      10              4            0
# 3             prilosec       3              1            1
# 4               lyrica       2              1            3
# ...                ...     ...            ...          ...
# 1031          accutane       7              3            3
# 1032        proair-hfa      10              4            0
# 1033          accutane       8              3            2
# 1034           divigel      10              4            0
# 1035    claripel-cream       8              3            1
#
#                                    condition  \
# 0     management of congestive heart failure
# 1                           birth prevention
# 2                           menstrual cramps
# 3                                acid reflux
# 4                               fibromyalgia
# ...                                      ...
# 1031                           acne vulgaris
# 1032                                  asthma
# 1033                              serve acne
# 1034                               menopause
# 1035       acne scarring & hyperpigmentation
#
#                                          benefitsReview  \
# 0     slowed the progression of left ventricular dys...
# 1     Although this type of birth control has more c...
# 2     I was used to having cramps so badly that they...
# 3     The acid reflux went away for a few months aft...
# 4     I think that the Lyrica was starting to help w...
# ...                                                 ...
# 1031  Detoxing effect by pushing out the system thro...
# 1032  The albuterol relieved the constriction, irrit...
# 1033                    Serve Acne has turned to middle
# 1034  My overall mood, sense of well being, energy l...
# 1035  Up until 2 years ago, it worked really well on...
#
#                                       sideEffectsReview  \
# 0     cough, hypotension , proteinuria, impotence , ...
# 1     Heavy Cycle, Cramps, Hot Flashes, Fatigue, Lon...
# 2            Heavier bleeding and clotting than normal.
# 3     Constipation, dry mouth and some mild dizzines...
# 4     I felt extremely drugged and dopey.  Could not...
# ...                                                 ...
# 1031  Hairloss, extreme dry skin, itchiness, raises ...
# 1032                I have experienced no side effects.
# 1033    Painfull muscles, problems with seeing at night
# 1034  No side effects of any kind were noted or appa...
# 1035  Have stopped using it and have also learned th...
#
#                                          commentsReview
# 0     monitor blood pressure , weight and asses for ...
# 1     I Hate This Birth Control, I Would Not Suggest...
# 2     I took 2 pills at the onset of my menstrual cr...
# 3     I was given Prilosec prescription at a dose of...
# 4                                             See above
# ...                                                 ...
# 1031  Treatment period is 3 months/12 weeks. Dosage ...
# 1032  I use the albuterol as needed because of aller...
# 1033  This drug is highly teratogenic ,females must ...
# 1034  Divigel is a topically applied Bio-Identical H...
# 1035               Stopped using it for the time being.
#
# [4143 rows x 8 columns]

# %%
# Group by drug name to get the average rating, effectiveness, and sideEffects,
# as well as a list of all conditions, benefitsReview, sideEffectsReview, and commentsReview
# for each distinct drug.
drugLib_combined = drugLib.groupby('urlDrugName').agg(rating=('rating','mean'),
                                                      effectiveness=('effectiveness','mean'),
                                                      sideEffects=('sideEffects','mean'),
                                                      condition=('condition', list),
                                                      benefitsReview=('benefitsReview', list),
                                                      sideEffectsReview=('sideEffectsReview', list),
                                                      commentsReview=('commentsReview', list)).reset_index()
drugLib_combined
# Out:
#     urlDrugName    rating  effectiveness  sideEffects  \
# 0       abilify  5.375000       2.625000     1.500000
# 1        acanya  9.000000       4.000000     1.000000
# 2      accolate  1.000000       0.000000     0.000000
# 3      accupril  9.000000       3.000000     0.000000
# 4      accutane  7.727273       3.522727     1.863636
# ..          ...       ...            ...          ...
# 536       zyban  5.562500       2.687500     2.562500
# 537     zyprexa  6.000000       2.857143     1.571429
# 538      zyrtec  7.781250       3.375000     1.093750
# 539    zyrtec-d  7.000000       3.250000     0.750000
# 540       zyvox  9.000000       4.000000     2.000000
#
#                                              condition  \
# 0    [depression not resolved with antidepressant d...
# 1                                        [cystic acne]
# 2              [capsuar contracture of breast implant]
# 3                                       [hypertension]
# 4    [acne, acne, severe acne, acne, acne, acne, ac...
# ..                                                 ...
# 536  [smoking, stop smoking, to quit smoking, smoki...
# 537  [agitation management r/t lewy body syndrome  ...
# 538  [for allergic condition and there after begnin...
# 539  [allergies, hay fever, pollen, dust, mold and ...
# 540                                             [mrsa]
#
#                                         benefitsReview  \
# 0    [While on abilify I can honestly say the depre...
# 1    [Acanya Gel treated cystic acne, blackheads, w...
# 2    [The benefits were not good, and this drug was...
# 3    [lower blood pressure in combination with Hyzaar]
# 4    [Eventually Cleared my moderate acne. Had reci...
# ..                                                 ...
# 536  [I stopped smoking after one week of starting ...
# 537  [The Zyprexa minimized agitative outbursts, Th...
# 538  [stopped sneezing runny nose and other allergi...
# 539  [Zyrtec D helped me live almost symptom free e...
# 540  [It cured the MRSA. Major downside was high pr...
#
#                                      sideEffectsReview  \
# 0    [but it caused memory loss and again an incide...
# 1    [Dryness, slight redness and a small amount of...
# 2    [I tolerated the medication very well.  I didn...
# 3                                [None I am aware of.]
# 4    [Hair loss! Not so much from my head, but othe...
# ..                                                 ...
# 536  [There was a feeling of complete disassociatio...
# 537  [The pt developed severe "gait freezing" , gai...
# 538  [my doctor toldme not to drive a car or swim w...
# 539  [While taking Zyrtec D I often had dry mouth, ...
# 540            [Yeast infection and minor queasiness.]
#
#                                         commentsReview
# 0    [I am only taking ativan & getting psychologic...
# 1    [The combination of clindamycin and benzoyl pe...
# 2    [I was required to take Accolate for three mon...
# 3    [Taken once daily in combination with Hyzaar. ...
# 4    [I can't remember ever having the initial flar...
# ..                                                 ...
# 536  [I took one 150 mg tablet for seven days, stop...
# 537  [Since many of these s/s are also s/s of the d...
# 538  [i was a person with sinusitis due to allergy....
# 539  [Take one pill every 12 hours, although on mor...
# 540  [Pill form, 2 a day. It was pretty simple. I h...
#
# [541 rows x 8 columns]

# %%
# Assign drugNameReduced column as the drug names with all special characters removed and converted to lower case
drugLib_combined['drugNameReduced'] = drugLib_combined['urlDrugName'].apply(lambda x: re.sub('[^A-Za-z0-9]', ' ', x.lower()))
drugLib_combined
# Out:
#     urlDrugName    rating  effectiveness  sideEffects  \
# 0       abilify  5.375000       2.625000     1.500000
# 1        acanya  9.000000       4.000000     1.000000
# 2      accolate  1.000000       0.000000     0.000000
# 3      accupril  9.000000       3.000000     0.000000
# 4      accutane  7.727273       3.522727     1.863636
# ..          ...       ...            ...          ...
# 536       zyban  5.562500       2.687500     2.562500
# 537     zyprexa  6.000000       2.857143     1.571429
# 538      zyrtec  7.781250       3.375000     1.093750
# 539    zyrtec-d  7.000000       3.250000     0.750000
# 540       zyvox  9.000000       4.000000     2.000000
#
#                                              condition  \
# 0    [depression not resolved with antidepressant d...
# 1                                        [cystic acne]
# 2              [capsuar contracture of breast implant]
# 3                                       [hypertension]
# 4    [acne, acne, severe acne, acne, acne, acne, ac...
# ..                                                 ...
# 536  [smoking, stop smoking, to quit smoking, smoki...
# 537  [agitation management r/t lewy body syndrome  ...
# 538  [for allergic condition and there after begnin...
# 539  [allergies, hay fever, pollen, dust, mold and ...
# 540                                             [mrsa]
#
#                                         benefitsReview  \
# 0    [While on abilify I can honestly say the depre...
# 1    [Acanya Gel treated cystic acne, blackheads, w...
# 2    [The benefits were not good, and this drug was...
# 3    [lower blood pressure in combination with Hyzaar]
# 4    [Eventually Cleared my moderate acne. Had reci...
# ..                                                 ...
# 536  [I stopped smoking after one week of starting ...
# 537  [The Zyprexa minimized agitative outbursts, Th...
# 538  [stopped sneezing runny nose and other allergi...
# 539  [Zyrtec D helped me live almost symptom free e...
# 540  [It cured the MRSA. Major downside was high pr...
#
#                                      sideEffectsReview  \
# 0    [but it caused memory loss and again an incide...
# 1    [Dryness, slight redness and a small amount of...
# 2    [I tolerated the medication very well.  I didn...
# 3                                [None I am aware of.]
# 4    [Hair loss! Not so much from my head, but othe...
# ..                                                 ...
# 536  [There was a feeling of complete disassociatio...
# 537  [The pt developed severe "gait freezing" , gai...
# 538  [my doctor toldme not to drive a car or swim w...
# 539  [While taking Zyrtec D I often had dry mouth, ...
# 540            [Yeast infection and minor queasiness.]
#
#                                         commentsReview drugNameReduced
# 0    [I am only taking ativan & getting psychologic...         abilify
# 1    [The combination of clindamycin and benzoyl pe...          acanya
# 2    [I was required to take Accolate for three mon...        accolate
# 3    [Taken once daily in combination with Hyzaar. ...        accupril
# 4    [I can't remember ever having the initial flar...        accutane
# ..                                                 ...             ...
# 536  [I took one 150 mg tablet for seven days, stop...           zyban
# 537  [Since many of these s/s are also s/s of the d...         zyprexa
# 538  [i was a person with sinusitis due to allergy....          zyrtec
# 539  [Take one pill every 12 hours, although on mor...        zyrtec d
# 540  [Pill form, 2 a day. It was pretty simple. I h...           zyvox
#
# [541 rows x 9 columns]

# %% [markdown]
# ### Cleaning up the drugsCom data

# %%
# Load data and combine train and test sets
drugsCom_train = pd.read_csv("Data/drugsComTrain_raw.tsv", sep='\t')
drugsCom_test = pd.read_csv("Data/drugsComTest_raw.tsv", sep='\t')
drugsCom = pd.concat([drugsCom_train, drugsCom_test])
drugsCom
# Out:
#        Unnamed: 0                  drugName                     condition  \
# 0          206461                 Valsartan  Left Ventricular Dysfunction
# 1           95260                Guanfacine                          ADHD
# 2           92703                    Lybrel                 Birth Control
# 3          138000                Ortho Evra                 Birth Control
# 4           35696  Buprenorphine / naloxone             Opiate Dependence
# ...           ...                       ...                           ...
# 53761      159999                 Tamoxifen     Breast Cancer, Prevention
# 53762      140714              Escitalopram                       Anxiety
# 53763      130945            Levonorgestrel                 Birth Control
# 53764       47656                Tapentadol                          Pain
# 53765      113712                 Arthrotec                      Sciatica
#
#                                                   review  rating  \
# 0      "It has no side effect, I take it in combinati...     9.0
# 1      "My son is halfway through his fourth week of ...     8.0
# 2      "I used to take another oral contraceptive, wh...     5.0
# 3      "This is my first time using any form of birth...     8.0
# 4      "Suboxone has completely turned my life around...     9.0
# ...                                                  ...     ...
# 53761  "I have taken Tamoxifen for 5 years. Side effe...    10.0
# 53762  "I&#039;ve been taking Lexapro (escitaploprgra...     9.0
# 53763  "I&#039;m married, 34 years old and I have no ...     8.0
# 53764  "I was prescribed Nucynta for severe neck/shou...     1.0
# 53765                                      "It works!!!"     9.0
#
#                      date  usefulCount
# 0            May 20, 2012           27
# 1          April 27, 2010          192
# 2       December 14, 2009           17
# 3        November 3, 2015           10
# 4       November 27, 2016           37
# ...                   ...          ...
# 53761  September 13, 2014           43
# 53762     October 8, 2016           11
# 53763   November 15, 2010            7
# 53764   November 28, 2011           20
# 53765  September 13, 2009           46
#
# [215063 rows x 7 columns]

# %%
# Drop first column
drugsCom = drugsCom.drop(['Unnamed: 0', 'date'], axis=1)
drugsCom
# Out:
#                        drugName                     condition  \
# 0                     Valsartan  Left Ventricular Dysfunction
# 1                    Guanfacine                          ADHD
# 2                        Lybrel                 Birth Control
# 3                    Ortho Evra                 Birth Control
# 4      Buprenorphine / naloxone             Opiate Dependence
# ...                         ...                           ...
# 53761                 Tamoxifen     Breast Cancer, Prevention
# 53762              Escitalopram                       Anxiety
# 53763            Levonorgestrel                 Birth Control
# 53764                Tapentadol                          Pain
# 53765                 Arthrotec                      Sciatica
#
#                                                   review  rating  usefulCount
# 0      "It has no side effect, I take it in combinati...     9.0           27
# 1      "My son is halfway through his fourth week of ...     8.0          192
# 2      "I used to take another oral contraceptive, wh...     5.0           17
# 3      "This is my first time using any form of birth...     8.0           10
# 4      "Suboxone has completely turned my life around...     9.0           37
# ...                                                  ...     ...          ...
# 53761  "I have taken Tamoxifen for 5 years. Side effe...    10.0           43
# 53762  "I&#039;ve been taking Lexapro (escitaploprgra...     9.0           11
# 53763  "I&#039;m married, 34 years old and I have no ...     8.0            7
# 53764  "I was prescribed Nucynta for severe neck/shou...     1.0           20
# 53765                                      "It works!!!"     9.0           46
#
# [215063 rows x 5 columns]

# %%
# Group by drug name to get the average rating and usefulCount
# as well as a list of all conditions and reviews
# for each distinct drug.
drugsCom_combined = drugsCom.groupby('drugName').agg(rating=('rating','mean'),
                                                      usefulCount=('usefulCount','sum'),
                                                      condition=('condition', list),
                                                      review=('review', list)).reset_index()
drugsCom_combined
# Out:
#                                   drugName     rating  usefulCount  \
# 0                A + D Cracked Skin Relief  10.000000            6
# 1                               A / B Otic  10.000000           38
# 2     Abacavir / dolutegravir / lamivudine   8.414286          901
# 3                    Abacavir / lamivudine  10.000000           11
# 4       Abacavir / lamivudine / zidovudine   9.000000            1
# ...                                    ...        ...          ...
# 3666                               ZzzQuil   2.000000           21
# 3667                 depo-subQ provera 104   5.500000            1
# 3668                                  ella   7.183099          677
# 3669                                femhrt   6.500000           81
# 3670                              pHisoHex  10.000000            0
#
#                                               condition  \
# 0                            [Bacterial Skin Infection]
# 1                          [Otitis Media, Otitis Media]
# 2     [HIV Infection, HIV Infection, HIV Infection, ...
# 3         [HIV Infection, HIV Infection, HIV Infection]
# 4                                       [HIV Infection]
# ...                                                 ...
# 3666                     [Insomnia, Insomnia, Insomnia]
# 3667                     [Birth Control, Birth Control]
# 3668  [Emergency Contraception, Emergency Contracept...
# 3669  [Postmenopausal Symptoms, 0</span> users found...
# 3670                  [Skin Disinfection, Preoperative]
#
#                                                  review
# 0     ["I have severe cracked skin on my hands.  I&#...
# 1     ["It numbs the pain. It makes my ear feel heav...
# 2     ["I have only been on it for 3 days now after ...
# 3     ["I&#039;ve used this since first diagnosed an...
# 4     ["I was diagnosed back in 2008 and have been o...
# ...                                                 ...
# 3666  ["I purchased the zzzquil and it did not work ...
# 3667  ["Not only did I gain ten pounds in just a few...
# 3668  ["Hey,\r\r\nSo I took the ellaOne about 7h aft...
# 3669  ["This medication completely changed my life f...
# 3670  ["Before Phisohex could only be purchased by p...
#
# [3671 rows x 5 columns]

# %%
# Assign drugNameReduced column as the drug names with all special characters removed and converted to lower case
drugsCom_combined['drugNameReduced'] = drugsCom_combined['drugName'].apply(lambda x: re.sub('[^A-Za-z0-9]', ' ', x.lower()))
drugsCom_combined
# Out:
#                                   drugName     rating  usefulCount  \
# 0                A + D Cracked Skin Relief  10.000000            6
# 1                               A / B Otic  10.000000           38
# 2     Abacavir / dolutegravir / lamivudine   8.414286          901
# 3                    Abacavir / lamivudine  10.000000           11
# 4       Abacavir / lamivudine / zidovudine   9.000000            1
# ...                                    ...        ...          ...
# 3666                               ZzzQuil   2.000000           21
# 3667                 depo-subQ provera 104   5.500000            1
# 3668                                  ella   7.183099          677
# 3669                                femhrt   6.500000           81
# 3670                              pHisoHex  10.000000            0
#
#                                               condition  \
# 0                            [Bacterial Skin Infection]
# 1                          [Otitis Media, Otitis Media]
# 2     [HIV Infection, HIV Infection, HIV Infection, ...
# 3         [HIV Infection, HIV Infection, HIV Infection]
# 4                                       [HIV Infection]
# ...                                                 ...
# 3666                     [Insomnia, Insomnia, Insomnia]
# 3667                     [Birth Control, Birth Control]
# 3668  [Emergency Contraception, Emergency Contracept...
# 3669  [Postmenopausal Symptoms, 0</span> users found...
# 3670                  [Skin Disinfection, Preoperative]
#
#                                                  review  \
# 0     ["I have severe cracked skin on my hands.  I&#...
# 1     ["It numbs the pain. It makes my ear feel heav...
# 2     ["I have only been on it for 3 days now after ...
# 3     ["I&#039;ve used this since first diagnosed an...
# 4     ["I was diagnosed back in 2008 and have been o...
# ...                                                 ...
# 3666  ["I purchased the zzzquil and it did not work ...
# 3667  ["Not only did I gain ten pounds in just a few...
# 3668  ["Hey,\r\r\nSo I took the ellaOne about 7h aft...
# 3669  ["This medication completely changed my life f...
# 3670  ["Before Phisohex could only be purchased by p...
#
#                            drugNameReduced
# 0                a   d cracked skin relief
# 1                               a   b otic
# 2     abacavir   dolutegravir   lamivudine
# 3                    abacavir   lamivudine
# 4       abacavir   lamivudine   zidovudine
# ...                                    ...
# 3666                               zzzquil
# 3667                 depo subq provera 104
# 3668                                  ella
# 3669                                femhrt
# 3670                              phisohex
#
# [3671 rows x 6 columns]

# %% [markdown]
# ### Merging the two datasets

# %%
# Joining the two tables using an outer join
df_combined=pd.merge(drugLib_combined,drugsCom_combined, on='drugNameReduced', how='outer')
df_combined
# Out:
#      urlDrugName  rating_x  effectiveness  sideEffects  \
# 0        abilify  5.375000       2.625000     1.500000
# 1         acanya  9.000000       4.000000     1.000000
# 2       accolate  1.000000       0.000000     0.000000
# 3       accupril  9.000000       3.000000     0.000000
# 4       accutane  7.727273       3.522727     1.863636
# ...          ...       ...            ...          ...
# 3722         NaN       NaN            NaN          NaN
# 3723         NaN       NaN            NaN          NaN
# 3724         NaN       NaN            NaN          NaN
# 3725         NaN       NaN            NaN          NaN
# 3726         NaN       NaN            NaN          NaN
#
#                                             condition_x  \
# 0     [depression not resolved with antidepressant d...
# 1                                         [cystic acne]
# 2               [capsuar contracture of breast implant]
# 3                                        [hypertension]
# 4     [acne, acne, severe acne, acne, acne, acne, ac...
# ...                                                 ...
# 3722                                                NaN
# 3723                                                NaN
# 3724                                                NaN
# 3725                                                NaN
# 3726                                                NaN
#
#                                          benefitsReview  \
# 0     [While on abilify I can honestly say the depre...
# 1     [Acanya Gel treated cystic acne, blackheads, w...
# 2     [The benefits were not good, and this drug was...
# 3     [lower blood pressure in combination with Hyzaar]
# 4     [Eventually Cleared my moderate acne. Had reci...
# ...                                                 ...
# 3722                                                NaN
# 3723                                                NaN
# 3724                                                NaN
# 3725                                                NaN
# 3726                                                NaN
#
#                                       sideEffectsReview  \
# 0     [but it caused memory loss and again an incide...
# 1     [Dryness, slight redness and a small amount of...
# 2     [I tolerated the medication very well.  I didn...
# 3                                 [None I am aware of.]
# 4     [Hair loss! Not so much from my head, but othe...
# ...                                                 ...
# 3722                                                NaN
# 3723                                                NaN
# 3724                                                NaN
# 3725                                                NaN
# 3726                                                NaN
#
#                                          commentsReview  \
# 0     [I am only taking ativan & getting psychologic...
# 1     [The combination of clindamycin and benzoyl pe...
# 2     [I was required to take Accolate for three mon...
# 3     [Taken once daily in combination with Hyzaar. ...
# 4     [I can't remember ever having the initial flar...
# ...                                                 ...
# 3722                                                NaN
# 3723                                                NaN
# 3724                                                NaN
# 3725                                                NaN
# 3726                                                NaN
#
#             drugNameReduced               drugName   rating_y  usefulCount  \
# 0                   abilify                Abilify   6.443508      23756.0
# 1                    acanya                 Acanya   7.345455        659.0
# 2                  accolate               Accolate  10.000000         57.0
# 3                  accupril               Accupril   5.000000         31.0
# 4                  accutane               Accutane   8.421769      10167.0
# ...                     ...                    ...        ...          ...
# 3722                 zytiga                 Zytiga   9.250000        423.0
# 3723                zzzquil                ZzzQuil   2.000000         21.0
# 3724  depo subq provera 104  depo-subQ provera 104   5.500000          1.0
# 3725                   ella                   ella   7.183099        677.0
# 3726               phisohex               pHisoHex  10.000000          0.0
#
#                                             condition_y  \
# 0     [Autism, Agitated State, Schizoaffective Disor...
# 1     [Acne, Acne, Acne, Acne, Acne, Acne, Acne, Acn...
# 2     [Asthma, Maintenance, Asthma, Maintenance, Ast...
# 3                                       [Heart Failure]
# 4     [Acne, Acne, Acne, Acne, Acne, 13</span> users...
# ...                                                 ...
# 3722  [Prostate Cance, Prostate Cance, Prostate Canc...
# 3723                     [Insomnia, Insomnia, Insomnia]
# 3724                     [Birth Control, Birth Control]
# 3725  [Emergency Contraception, Emergency Contracept...
# 3726                  [Skin Disinfection, Preoperative]
#
#                                                  review
# 0     ["My child has been on Abilify for a while now...
# 1     ["Thank God i read the reviews before applying...
# 2     ["I have had asthma all my life.  About 10 yea...
# 3     ["Works well if you can tolerate the annoying ...
# 4     ["When I was a 15 year old freshman in high sc...
# ...                                                 ...
# 3722  ["PSA 28 to 4 in one week. Fatigue only side e...
# 3723  ["I purchased the zzzquil and it did not work ...
# 3724  ["Not only did I gain ten pounds in just a few...
# 3725  ["Hey,\r\r\nSo I took the ellaOne about 7h aft...
# 3726  ["Before Phisohex could only be purchased by p...
#
# [3727 rows x 14 columns]

# %% [markdown]
# ##### After merging the two datasets, we combined any columns that represented the same feature into one column.

# %%
# Functions for combining columns that represent the same type of feature

def rating (row):
    """Returns the average rating of rating_x and rating_y if they both have existing values.
    Otherwise, only returns the one that is not NaN"""
    
    # If the rating_x value of the given row is NaN, return the value of rating_y
    if math.isnan(row['rating_x']):
        return row['rating_y']
    # If the rating_y value of the given row is NaN, return the value of rating_x
    elif math.isnan(row['rating_y']):
        return row['rating_x']
    # If both rating_x and rating_y have existing values, return the average
    else:
        return (row['rating_x'] + row['rating_y'])/2
    
def condition (row):
    """Combine condition_x and condition_y values into one list"""
    
    if isinstance(row['condition_x'], list):
        # If the condition_x and condition_y values of the given row are both lists, 
        # return their values as one list
        if isinstance(row['condition_y'], list):
            return row['condition_x'] + row['condition_y']
        # If the condition_x value is a list, but not the condition_y value, return the condition_x value
        else:
            return row['condition_x'] 
    # If the condition_y value is a list, but not the condition_x value, return the condition_y value
    else:
        return row['condition_y']
    
def review (row):
    """Combine commentsReview and review values into one list"""
    if isinstance(row['commentsReview'], list):
        # If the commentsReview and review values of the given row are both lists, 
        # return their values as one list
        if isinstance(row['review'], list):
            return row['commentsReview'] + row['review']
        # If the commentsReview value is a list, but not the review value, return the commentsReview
        else:
            return row['commentsReview']   
    # If the review value is a list, but not the commentsReview value, return the review value
    else:
        return row['review']

# %%
# Create new rating column of average rating_x and rating_y values
df_combined['rating'] = df_combined.apply (lambda row: rating(row), axis=1)

# Create new condition column of concatenated condition_x and condition_y values
df_combined['condition'] = df_combined.apply (lambda row: condition(row), axis=1)

# Create new reviews column of concatenated commentsReview and review values
df_combined['reviews'] = df_combined.apply (lambda row: review(row), axis=1)

df_combined
# Out:
#      urlDrugName  rating_x  effectiveness  sideEffects  \
# 0        abilify  5.375000       2.625000     1.500000
# 1         acanya  9.000000       4.000000     1.000000
# 2       accolate  1.000000       0.000000     0.000000
# 3       accupril  9.000000       3.000000     0.000000
# 4       accutane  7.727273       3.522727     1.863636
# ...          ...       ...            ...          ...
# 3722         NaN       NaN            NaN          NaN
# 3723         NaN       NaN            NaN          NaN
# 3724         NaN       NaN            NaN          NaN
# 3725         NaN       NaN            NaN          NaN
# 3726         NaN       NaN            NaN          NaN
#
#                                             condition_x  \
# 0     [depression not resolved with antidepressant d...
# 1                                         [cystic acne]
# 2               [capsuar contracture of breast implant]
# 3                                        [hypertension]
# 4     [acne, acne, severe acne, acne, acne, acne, ac...
# ...                                                 ...
# 3722                                                NaN
# 3723                                                NaN
# 3724                                                NaN
# 3725                                                NaN
# 3726                                                NaN
#
#                                          benefitsReview  \
# 0     [While on abilify I can honestly say the depre...
# 1     [Acanya Gel treated cystic acne, blackheads, w...
# 2     [The benefits were not good, and this drug was...
# 3     [lower blood pressure in combination with Hyzaar]
# 4     [Eventually Cleared my moderate acne. Had reci...
# ...                                                 ...
# 3722                                                NaN
# 3723                                                NaN
# 3724                                                NaN
# 3725                                                NaN
# 3726                                                NaN
#
#                                       sideEffectsReview  \
# 0     [but it caused memory loss and again an incide...
# 1     [Dryness, slight redness and a small amount of...
# 2     [I tolerated the medication very well.  I didn...
# 3                                 [None I am aware of.]
# 4     [Hair loss! Not so much from my head, but othe...
# ...                                                 ...
# 3722                                                NaN
# 3723                                                NaN
# 3724                                                NaN
# 3725                                                NaN
# 3726                                                NaN
#
#                                          commentsReview  \
# 0     [I am only taking ativan & getting psychologic...
# 1     [The combination of clindamycin and benzoyl pe...
# 2     [I was required to take Accolate for three mon...
# 3     [Taken once daily in combination with Hyzaar. ...
# 4     [I can't remember ever having the initial flar...
# ...                                                 ...
# 3722                                                NaN
# 3723                                                NaN
# 3724                                                NaN
# 3725                                                NaN
# 3726                                                NaN
#
#             drugNameReduced               drugName   rating_y  usefulCount  \
# 0                   abilify                Abilify   6.443508      23756.0
# 1                    acanya                 Acanya   7.345455        659.0
# 2                  accolate               Accolate  10.000000         57.0
# 3                  accupril               Accupril   5.000000         31.0
# 4                  accutane               Accutane   8.421769      10167.0
# ...                     ...                    ...        ...          ...
# 3722                 zytiga                 Zytiga   9.250000        423.0
# 3723                zzzquil                ZzzQuil   2.000000         21.0
# 3724  depo subq provera 104  depo-subQ provera 104   5.500000          1.0
# 3725                   ella                   ella   7.183099        677.0
# 3726               phisohex               pHisoHex  10.000000          0.0
#
#                                             condition_y  \
# 0     [Autism, Agitated State, Schizoaffective Disor...
# 1     [Acne, Acne, Acne, Acne, Acne, Acne, Acne, Acn...
# 2     [Asthma, Maintenance, Asthma, Maintenance, Ast...
# 3                                       [Heart Failure]
# 4     [Acne, Acne, Acne, Acne, Acne, 13</span> users...
# ...                                                 ...
# 3722  [Prostate Cance, Prostate Cance, Prostate Canc...
# 3723                     [Insomnia, Insomnia, Insomnia]
# 3724                     [Birth Control, Birth Control]
# 3725  [Emergency Contraception, Emergency Contracept...
# 3726                  [Skin Disinfection, Preoperative]
#
#                                                  review     rating  \
# 0     ["My child has been on Abilify for a while now...   5.909254
# 1     ["Thank God i read the reviews before applying...   8.172727
# 2     ["I have had asthma all my life.  About 10 yea...   5.500000
# 3     ["Works well if you can tolerate the annoying ...   7.000000
# 4     ["When I was a 15 year old freshman in high sc...   8.074521
# ...                                                 ...        ...
# 3722  ["PSA 28 to 4 in one week. Fatigue only side e...   9.250000
# 3723  ["I purchased the zzzquil and it did not work ...   2.000000
# 3724  ["Not only did I gain ten pounds in just a few...   5.500000
# 3725  ["Hey,\r\r\nSo I took the ellaOne about 7h aft...   7.183099
# 3726  ["Before Phisohex could only be purchased by p...  10.000000
#
#                                               condition  \
# 0     [depression not resolved with antidepressant d...
# 1     [cystic acne, Acne, Acne, Acne, Acne, Acne, Ac...
# 2     [capsuar contracture of breast implant, Asthma...
# 3                         [hypertension, Heart Failure]
# 4     [acne, acne, severe acne, acne, acne, acne, ac...
# ...                                                 ...
# 3722  [Prostate Cance, Prostate Cance, Prostate Canc...
# 3723                     [Insomnia, Insomnia, Insomnia]
# 3724                     [Birth Control, Birth Control]
# 3725  [Emergency Contraception, Emergency Contracept...
# 3726                  [Skin Disinfection, Preoperative]
#
#                                                 reviews
# 0     [I am only taking ativan & getting psychologic...
# 1     [The combination of clindamycin and benzoyl pe...
# 2     [I was required to take Accolate for three mon...
# 3     [Taken once daily in combination with Hyzaar. ...
# 4     [I can't remember ever having the initial flar...
# ...                                                 ...
# 3722  ["PSA 28 to 4 in one week. Fatigue only side e...
# 3723  ["I purchased the zzzquil and it did not work ...
# 3724  ["Not only did I gain ten pounds in just a few...
# 3725  ["Hey,\r\r\nSo I took the ellaOne about 7h aft...
# 3726  ["Before Phisohex could only be purchased by p...
#
# [3727 rows x 17 columns]

# %% [markdown]
# ##### To convert reviews into numerical values, we perfomed sentiment analysis on those columns to get a sentiment score.

# %%
def sentiment_analysis(review_list):
    """Performs sentiment analysis on every review in the given list. Then, takes the average of each sentiment
    score. If there are no given reviews to analyze, automatically assigns score of 0.
    A negative score represents a negative review, a score of 0 represents a neutral review, and 
    a positive score represents a positive review."""
    
    sia = SentimentIntensityAnalyzer()
    review_scores = []
    
    if isinstance(review_list, list):
        # Iterate through each review and assign a sentiment score
        # Then, return the average of all the sentiment scores
        for review in review_list:
            score = sia.polarity_scores(str(review))["compound"]
            review_scores.append(score)
        return np.mean(review_scores)
    
    # If the given object is not a list of reviews, return a score of 0
    return 0

# %%
# Sentiment analysis on the review columns
df_combined["sentiment_score"] = df_combined["reviews"].apply(lambda x: sentiment_analysis(x))
df_combined["benefits_sentiment_score"] = df_combined["benefitsReview"].apply(lambda x: sentiment_analysis(x))
df_combined["side_effects_sentiment_score"] = df_combined["sideEffectsReview"].apply(lambda x: sentiment_analysis(x))

# Drop columns we no longer need
df_combined = df_combined.drop(['rating_x', 'rating_y', 'condition_x', 'condition_y', 'commentsReview', 
                                'review', 'reviews', 'benefitsReview', 'sideEffectsReview'], axis=1)

# %%
df_combined
# Out:
#      urlDrugName  effectiveness  sideEffects        drugNameReduced  \
# 0        abilify       2.625000     1.500000                abilify
# 1         acanya       4.000000     1.000000                 acanya
# 2       accolate       0.000000     0.000000               accolate
# 3       accupril       3.000000     0.000000               accupril
# 4       accutane       3.522727     1.863636               accutane
# ...          ...            ...          ...                    ...
# 3722         NaN            NaN          NaN                 zytiga
# 3723         NaN            NaN          NaN                zzzquil
# 3724         NaN            NaN          NaN  depo subq provera 104
# 3725         NaN            NaN          NaN                   ella
# 3726         NaN            NaN          NaN               phisohex
#
#                    drugName  usefulCount     rating  \
# 0                   Abilify      23756.0   5.909254
# 1                    Acanya        659.0   8.172727
# 2                  Accolate         57.0   5.500000
# 3                  Accupril         31.0   7.000000
# 4                  Accutane      10167.0   8.074521
# ...                     ...          ...        ...
# 3722                 Zytiga        423.0   9.250000
# 3723                ZzzQuil         21.0   2.000000
# 3724  depo-subQ provera 104          1.0   5.500000
# 3725                   ella        677.0   7.183099
# 3726               pHisoHex          0.0  10.000000
#
#                                               condition  sentiment_score  \
# 0     [depression not resolved with antidepressant d...         0.019727
# 1     [cystic acne, Acne, Acne, Acne, Acne, Acne, Ac...         0.248393
# 2     [capsuar contracture of breast implant, Asthma...         0.465575
# 3                         [hypertension, Heart Failure]         0.259300
# 4     [acne, acne, severe acne, acne, acne, acne, ac...         0.167362
# ...                                                 ...              ...
# 3722  [Prostate Cance, Prostate Cance, Prostate Canc...        -0.132458
# 3723                     [Insomnia, Insomnia, Insomnia]         0.208200
# 3724                     [Birth Control, Birth Control]         0.255600
# 3725  [Emergency Contraception, Emergency Contracept...        -0.354651
# 3726                  [Skin Disinfection, Preoperative]         0.708800
#
#       benefits_sentiment_score  side_effects_sentiment_score
# 0                     0.254600                     -0.264713
# 1                     0.126300                      0.000000
# 2                    -0.286900                      0.564800
# 3                    -0.526700                      0.000000
# 4                     0.172561                     -0.189648
# ...                        ...                           ...
# 3722                  0.000000                      0.000000
# 3723                  0.000000                      0.000000
# 3724                  0.000000                      0.000000
# 3725                  0.000000                      0.000000
# 3726                  0.000000                      0.000000
#
# [3727 rows x 11 columns]

# %% [markdown]
# ##### For rows that had NaN values for effectiveness and/or sideEffects, we replaced the NaN values with the mean effectiveness and sideEffects scores.

# %%
# Calculate mean effectiveness
effectiveness = df_combined['effectiveness']
effectiveness = effectiveness.dropna()
effectiveness_mean = effectiveness.mean()

# Calculate mean sideEffects
sideEffects = df_combined['sideEffects']
sideEffects = sideEffects.dropna()
sideEffects_mean = sideEffects.mean()

# Assign Nan values to mean effectiveness/sideEffects value
df_combined['effectiveness'] = df_combined['effectiveness'].fillna(effectiveness_mean)
df_combined['sideEffects'] = df_combined['sideEffects'].fillna(sideEffects_mean)

df_combined
# Out:
#      urlDrugName  effectiveness  sideEffects        drugNameReduced  \
# 0        abilify       2.625000     1.500000                abilify
# 1         acanya       4.000000     1.000000                 acanya
# 2       accolate       0.000000     0.000000               accolate
# 3       accupril       3.000000     0.000000               accupril
# 4       accutane       3.522727     1.863636               accutane
# ...          ...            ...          ...                    ...
# 3722         NaN       2.933651     1.193745                 zytiga
# 3723         NaN       2.933651     1.193745                zzzquil
# 3724         NaN       2.933651     1.193745  depo subq provera 104
# 3725         NaN       2.933651     1.193745                   ella
# 3726         NaN       2.933651     1.193745               phisohex
#
#                    drugName  usefulCount     rating  \
# 0                   Abilify      23756.0   5.909254
# 1                    Acanya        659.0   8.172727
# 2                  Accolate         57.0   5.500000
# 3                  Accupril         31.0   7.000000
# 4                  Accutane      10167.0   8.074521
# ...                     ...          ...        ...
# 3722                 Zytiga        423.0   9.250000
# 3723                ZzzQuil         21.0   2.000000
# 3724  depo-subQ provera 104          1.0   5.500000
# 3725                   ella        677.0   7.183099
# 3726               pHisoHex          0.0  10.000000
#
#                                               condition  sentiment_score  \
# 0     [depression not resolved with antidepressant d...         0.019727
# 1     [cystic acne, Acne, Acne, Acne, Acne, Acne, Ac...         0.248393
# 2     [capsuar contracture of breast implant, Asthma...         0.465575
# 3                         [hypertension, Heart Failure]         0.259300
# 4     [acne, acne, severe acne, acne, acne, acne, ac...         0.167362
# ...                                                 ...              ...
# 3722  [Prostate Cance, Prostate Cance, Prostate Canc...        -0.132458
# 3723                     [Insomnia, Insomnia, Insomnia]         0.208200
# 3724                     [Birth Control, Birth Control]         0.255600
# 3725  [Emergency Contraception, Emergency Contracept...        -0.354651
# 3726                  [Skin Disinfection, Preoperative]         0.708800
#
#       benefits_sentiment_score  side_effects_sentiment_score
# 0                     0.254600                     -0.264713
# 1                     0.126300                      0.000000
# 2                    -0.286900                      0.564800
# 3                    -0.526700                      0.000000
# 4                     0.172561                     -0.189648
# ...                        ...                           ...
# 3722                  0.000000                      0.000000
# 3723                  0.000000                      0.000000
# 3724                  0.000000                      0.000000
# 3725                  0.000000                      0.000000
# 3726                  0.000000                      0.000000
#
# [3727 rows x 11 columns]

# %% [markdown]
# ##### For the conditions column, we cleaned up each list of conditions by fixing spelling errors and removing duplicate conditions.

# %%
def reduce_condition(condition_list):
    """Clean up the given list of conditions fix spelling errors, make all conditions lower case,
    and remove redundant and irrelevant values.
    """
    # Remove all floats
    conditions = [b for b in condition_list if not isinstance(b, float)]
    
    # Iterate through each condition to clean up spelling
    for condition in conditions:
        # make lowercase and fix double spaces
        condition_lc = str(condition).lower().replace("  ", " ")
        # Use TextBlob to fix spelling errors
        gfg = TextBlob(condition_lc)
        gfg = gfg.correct()
        conditions[conditions.index(condition)] = str(gfg)
        
    # remove items that contain '<' or '/'
    conditions = [x for x in conditions if (not '<' in x and not '/' in x)]
    # split by 'and'
    conditions = [y for x in conditions for y in x.split(' and ')]
    
    # Convert the list to a set to remove redundant values
    cond_set = set(conditions)
        
    return list(cond_set)

# %%
# Reduce the conditions column and save as reduced_conditions column
df_combined['reduced_conditions'] = df_combined['condition'].apply(lambda x: reduce_condition(x))
df_combined

# %% [markdown]
# ##### Saving data as csv files to load into Neo4J

# %%
# Save as csv to load as Drug nodes in Neo4J
df_combined.to_csv('/csv/drug_info.csv')

# %%
# Get set of all unique conditions
condition_set = set()
for row in range(3723):
    condition_list = literal_eval(str(df_combined['reduced_conditions'][row]))
    condition_set.update(condition_list)
    
# Store conditions in a DataFrame and save as csv file
df_conditions = pd.DataFrame(list(condition_set), columns=['condition'])

# Save as csv to load as Condition nodes in Neo4J
df_conditions.to_csv('/csv/conditions.csv')
# Out:
# {'chronic idiopathic urticaria with neuritis',
#  'extreme hot flashes',
#  'red spot on the cheek',
#  'menopause',
#  'diabetes, type 2',
#  'urgent privation',
#  'high deficiency & his',
#  'ascariasis',
#  'pityriasis cuba paris',
#  'gonococcal infection, uncomplicated',
#  'malign glioma',
#  'dystonia',
#  'chronic depression',
#  'anti-raging',
#  'polycystic ovarian syndrome',
#  'lupus-like system autoimmune condition',
#  'multilocular goitre',
#  'opiates dependency',
#  'double ear infections',
#  'cocaine dependency',
#  'spring galleries, clergy cough',
#  'temporomandibular joint disorder (tm)',
#  'dissociative identity disorder',
#  'impetigo',
#  'bipolar disorder, old behavior',
#  'to help me sleep after having a rapid heartfelt up',
#  'primary hypersomnia',
#  'least infections due to dryness',
#  'interactive thyreoid',
#  'submental fullness',
#  'sleeplessness - depression',
#  'antibiotic to treat oral infection',
#  'there after begging of',
#  'conjunctivitis, bacterial',
#  'acute ostitis externa',
#  'nicotine addition',
#  'esophageal varices haemorrhage prophylaxis',
#  'itchy watery eyes',
#  'dry eyes',
#  "keener's granulomatosis",
#  'female problems, trying to get pregnant, population',
#  'severe pus',
#  'high level of prolactin',
#  'klebsiella pneumonia infection',
#  'inflammatory conditions',
#  'pulmonary hypertension',
#  'add (predominantly inattentive)',
#  'receding airline',
#  'chest infection',
#  'solar extraction',
#  'pneumococcal disease prophylaxis',
#  'elevated cholestrol',
#  'severe stomach pains',
#  'grain',
#  'narcolepsy',
#  'ra, s�grew syndrome',
#  'bronchiectasis',
#  'loss of bone mass',
#  'mycobacterium aim-intracellulare, treatment',
#  'severe pain',
#  'seborrheic dermatitis',
#  'oedema',
#  'panic attacks',
#  'asthma, emphysema',
#  'esophageal candidiasis',
#  'follicular lympho',
#  'attention deficit problems, concentration difficult',
#  'my',
#  'very oily skin',
#  'low he',
#  'restlessness',
#  't care',
#  'sepsis',
#  'ovarian cysts.',
#  'birth control, heavy periods',
#  'eyelashes hypotrichosis',
#  'surgical memopause',
#  'lose weight',
#  'anxiety, depression',
#  'dumping syndrome',
#  'lichen plans',
#  'major depression',
#  'diareaha',
#  'ohio addition',
#  'glioblastoma multi',
#  'anxiety due to relationship stress',
#  'neuropathic back pain',
#  'bacterial endocarditis prevention',
#  'anti raging',
#  'cm prophylaxis',
#  'herpes foster',
#  'low thyreoid production',
#  'pregnancy prevention',
#  'sarcoidosis',
#  'psychic symptoms',
#  'prophetic heart valves, tissue valves - thrombosis prophylaxis',
#  "raynaud's disease",
#  'abdominal pain',
#  'chronic pancreatitis',
#  'anaemia associated with chronic renal failure',
#  'intrinsic raging',
#  'pass. rheumatoid earth. lupus, or fibromyalgia',
#  'ostoarthritis, severe body',
#  'chronic regional pain syndrome',
#  'tooth infection',
#  'arthritis pain, neck injury',
#  'bacterial skin infection',
#  'lower respiratory tract infection',
#  'schizoaffective disorder',
#  'cellulitis (skin infection on my leg)',
#  'post surgery stomach pain',
#  'post hemorrhoidectomy',
#  'depression;',
#  'gastrointestinal disorder',
#  'psoriasis arthritis',
#  'menapause',
#  'uveitis, posters',
#  'crowns disease, psoriasis arthritis',
#  'parkinsonism',
#  'diagnosed',
#  'benzodiazepine withdrawal',
#  'sciatica',
#  'arthritis in knees',
#  'only at age 41',
#  'high blood pressure -- diuretics',
#  'ovarian cysts',
#  'post traumatic stress disorder',
#  'never muscle spasms lower back',
#  'nasal clergy',
#  'chronic inflammatory demyelinating polyradiculoneuropathy',
#  'niacin deficiency',
#  'periodic limb movement disorder',
#  'depression, a.d.d., mood inability',
#  'deep vein thrombosis',
#  'tm - inflammation',
#  'ocular rosacea',
#  'cos',
#  'solid tumours',
#  'skin problems - acne, balckheads',
#  'gout',
#  'persistent chest infection symptoms',
#  'clergy, funny nose, hay fever',
#  'pseudotumor cerebro',
#  'excessive coughing, later diagnosed as pneumonia',
#  'rheumatoid arthritis joint pain, fibromyalgia',
#  'reversal of ovoid sedition',
#  'pseudobulbar affect',
#  'anxiety, old',
#  'opiates dependence',
#  "corn's syndrome",
#  'nonalcoholic fatty liver disease',
#  'bacterial lung infection',
#  'old, bipolar disease',
#  'mycoplasma bronchitis',
#  'lime disease',
#  'shilling test',
#  'swollen knee',
#  'pain after surgery',
#  'stopping smoking',
#  'neurosurgery',
#  'postural orthostatic tachycardia syndrome',
#  'chronic fatigue syndrome',
#  'hypthyroidism',
#  'urinary retention',
#  'photoaging',
#  'osteochondritis',
#  'always crying',
#  'undifferentiated connective tissue disease',
#  'he 2',
#  'rapid cycling i polar',
#  'sinus infection',
#  'kidney infection',
#  'tinel bare',
#  'diarrhoea, chronic',
#  'mononucleosis',
#  'nasal galleries',
#  'hormonal balances',
#  'human papilloma virus',
#  'reflux',
#  'glioma',
#  'croup',
#  'depression',
#  'hot flash sleep problems',
#  'insult resistance',
#  'high blood cholestrol levels',
#  'dientamoeba fragility',
#  'early onset osteoporosis',
#  'capsular contracture of breast plant',
#  'hyperlipoproteinemia type iv, elevated all',
#  'prevention of cardiovascular disease',
#  'anaplastic oligodendroglioma',
#  'gastric esophageal reflux',
#  'moterol)',
#  'meningitis, meningococcal',
#  'familiar mediterranean five',
#  'prevention of osteoporosis',
#  'muscle pain',
#  'indoor galleries',
#  'serotonin balance, mood swing',
#  'pain from broken arm',
#  'migraines, back spasm, insomnia',
#  'nausea after eating',
#  'hyperphosphatemia of renal failure',
#  'anti-raging, acne',
#  'night sweats',
#  'myotonia congenital',
#  'basal cell carcinoma',
#  'seizure',
#  'muscle relevant',
#  'to stop smoking',
#  'contact dermatitis',
#  'unable to sleep because of pain',
#  'substitute for a arbitrate',
#  'high cholestrol, familiar homozygous',
#  'myofascial pain',
#  'is',
#  'after 42 years, quit smoking',
#  'fibromyalgia',
#  'respiratory infection',
#  'nummular eczema',
#  'migrate relief',
#  'ovoid-induced constipation',
#  'slipped disc in back',
#  'stomach cancer',
#  'delayed gastric emptying-nausea',
#  'ras associated with sleep anna',
#  'long term chronic',
#  'system fungus',
#  'over weight',
#  'insult resistance syndrome',
#  'giant cell tumor of bone',
#  'pseudogout, prophylaxis',
#  'skin damage',
#  'skin cancers',
#  'infected site of real surgery',
#  'excessive testosterone levels',
#  'iron deficiency anaemia',
#  'menstrual pain',
#  'ichthyosis',
#  'irregular cycle',
#  'reduce wrinkles',
#  'diabetic macular oedema',
#  'migraines',
#  'fatigue, depression',
#  'hormonal acne',
#  'bowels cancer on tip of nose',
#  'lactation',
#  'severe knee pain',
#  'palpitating',
#  'parkinsonian them',
#  'diarreah',
#  'postoperative ocular inflammation',
#  'pemphigoid',
#  'dermatomyositis',
#  'spondyloarthritis',
#  'prostatitis (ironically)',
#  'rabies prophylaxis',
#  'inflammatory arthritis',
#  'chronic nerve pain from back surgery',
#  'juvenile rheumatoid arthritis',
#  'wilson disease',
#  'irregular periods',
#  'chronic cystitis',
#  'pain in legs (diagnosis restless leg syndrome)',
#  'cold, acute',
#  'chest pain',
#  'high total cholestrol',
#  'pruritus of partial ciliary obstruction',
#  'severe insomnia',
#  'avoid bacterial infection',
#  'bulbous pemphigoid',
#  'anti-raging prophylactic',
#  'roseola on the face',
#  'narcolepsy, sleep anna, bipolar disorder',
#  'low back pain',
#  'lactation pigmentation',
#  'abdominal distension',
#  'severe back pain resulting from a herniated disc',
#  'influenza prophylaxis',
#  'gout, prophylaxis',
#  'dust clergy',
#  'after an angiogram',
#  'cancer related pain',
#  'post-menopausal osteopenia',
#  'hay fever',
#  'sinus congestion',
#  'wolff-atkinson-white syndrome',
#  'myelitis',
#  'loss of bone density',
#  'extremely dry skin',
#  'anxiety,depression',
#  'allergic retinitis',
#  'stress, feeling overwhelmed',
#  'heart cond.',
#  'wrinkles, furrows',
#  'scleroderma',
#  'allegro',
#  'weight loss',
#  'skin rash',
#  'pulmonary embolism, first event',
#  'chronic pain, fibromyalgia',
#  'osteochondral injury of the tales, left ankle',
#  'water in ear',
#  'adult human growth harmony deficiency',
#  'mild acne',
#  'system mastocytosis',
#  'cesarean',
#  'ulcerative politics, maintece',
#  'osteolytic bone lesions of multiple myeloma',
#  'she (lupus), rheumatoid arthritis',
#  'irritated skin',
#  'high intraocular pressure (glaucoma)',
#  'hypothyroid problem',
#  'restless legs',
#  'typical breast tipsy',
#  'strokes',
#  'dermatitis herpes',
#  'bipolar disorder',
#  'insomnia',
#  'congested sinuses',
#  'longer eyelashes',
#  'adult add',
#  'upper respiratory infection',
#  'hashimotos syndrome - hypothyroid symptoms',
#  'bolivia',
#  'chronic pelvic pain',
#  'mild arthritis in knees',
#  'skin problem',
#  'malaria',
#  'hypthyroidsim',
#  'oophorectomy',
#  'anxiety induced palpitating',
#  'menopausal systems',
#  'zollinger-allison syndrome',
#  'post part depression',
#  'perimenopausal symptoms',
#  'attention deficit disorder (inattentive type)',
#  'final tonsils',
#  'acne & sun damaged skin',
#  'primary dysmenorrhea',
#  'abortion',
#  'stop smoking',
#  'elevated cholestrol level',
#  'skin or soft tissue infection',
#  'chronic urinary',
#  'add - mild depression',
#  'lime disease, arthritis',
#  'panic disorder, agoraphobia',
#  'again influenza',
#  'osteo-arthritis',
#  'pathological hypersecretory conditions',
#  'diarrhoea',
#  'forehead frown lines',
#  'ischaemic stroke',
#  'major sinus infection',
#  'a heart block',
#  'topical disinfection',
#  'diabetic',
#  'hepatic encephalopathy',
#  'menapouse',
#  'migraines)',
#  'maintains',
#  'acne, malasha',
#  'opposition defiant disorder',
#  'crashing fatigue, hot flashes, mood swing',
#  'system candidiasis',
#  'performance anxiety',
#  'environmental galleries',
#  'osteopenia',
#  'skin',
#  'tendinitis of the foot, specifically big toe',
#  'after birth thyreoid not working to normal level',
#  'cold sore below lip',
#  'i-polar, depression',
#  'severe',
#  'difficulty sleeping',
#  'age spots',
#  'dry skin',
#  'nephrocalcinosis',
#  "atkinson's",
#  'uterine bleeding',
#  'renal cell carcinoma',
#  'nocturnal myoclonus (like restless leg syndrome)',
#  'nocturnal leg cramps',
#  'depression, nomination, anxiety',
#  'hyperbilirubinemia',
#  'eyelashes loss',
#  'fibromylgia',
#  'difficulty sleeping because of nervous system probe',
#  'dental abscess',
#  'excessive fears',
#  'tonic clonic seizures',
#  'dementia',
#  'heavy menstrual bleeding',
#  'hyperuricemia secondary to chemotherapy',
#  'diabetes',
#  'nerve pain',
#  'deep vein thrombosis, first event',
#  'population induction',
#  'quitting smoking',
#  'anti-wrinkle',
#  'insomnia, stimulant-associated',
#  'ankylosing spondalytis',
#  'family history of heart',
#  'to lose 30 pounds',
#  'hypothroidism after radioactive iodine',
#  'pain relief - toothache',
#  'alcohol dependence',
#  'partial hysterectomy',
#  'pudendal neuralgia',
#  'postpartum breast pain',
#  'tooth abscess',
#  'haemangioma',
#  'pelvic inflammatory disease',
#  'th level was low no clinical symptoms',
#  'galleries sneering , watery funny nose',
#  'pneumonia with associated cough',
#  'severe migrate',
#  'vaginal dryness',
#  'recurring cold sores',
#  'cervical spondylosis',
#  'burning feeling in throat',
#  'heart failure',
#  "alzheimer's",
#  'melanoma, metastatic',
#  'hyperekplexia',
#  'plastic anaemia',
#  'heart racing',
#  'razor bump',
#  'singles',
#  'shortness of breath, paranoia',
#  'erictile dysfunction',
#  'abnormal uterine bleeding',
#  'blepharitis',
#  'chest infections',
#  'bipolar i',
#  'prevention of thromboembolism in trial fibrillation',
#  'acne, photoaging',
#  'eye galleries',
#  'surgery recovery',
#  'hepatic tm',
#  'psoriasis',
#  'pain from recovering from abdominal surgery',
#  'stress',
#  'major chronic depression disorder',
#  'lupus',
#  'hyperparathyroidism secondary to renal impairment',
#  'ulcerative politics, active',
#  'sleep aid',
#  'hirsutism',
#  'allergic rash',
#  'postherpetic neuralgia',
#  'insomnia due to peri-menopause',
#  'secondary cutaneous bacterial infections',
#  'retinitis',
#  'hypertention',
#  'mrs infected hip resurfacing.',
#  'hypomagnesemia',
#  'gallbladder disease',
#  'leukocytoclastic vasculitis',
#  'conjunctivitis',
#  'menstrual cramps',
#  'hypothyrodism',
#  'indigestion',
#  'joint infection',
#  'shift disorder',
#  'autoimmune hemolytic anaemia',
#  'clergy',
#  'post surgery extreme pain',
#  'lime disease, neuralgic',
#  'memopause',
#  'hair less',
#  'depression, social anxiety disorder',
#  'chronic sinus infection (long term), post nasal dr',
#  'chronic severe insomnia',
#  'to quit smoking',
#  'preventing pregnancy',
#  "coman's syndrome",
#  'platelets aggregation inhibition',
#  'meningococcal meningitis prophylaxis',
#  'have',
#  'cystitis',
#  'blood clots',
#  'vewy body dementia',
#  'pregnancy avoidance',
#  'hydrocephalus',
#  'anxiety.',
#  'hypertriglyceridemia',
#  'adult onset acne',
#  'tremor',
#  'panic depression',
#  'allergic urticaria',
#  'tinel corporal',
#  'iritis',
#  'skin raging',
#  'high ll',
#  'menopause symptoms such as hot flashes,sleepless',
#  'thyrotoxicosis',
#  'preventing malaria',
#  'neutral pain',
#  'cornea ulcer',
#  'anti age benefits',
#  'high interoccular pressure',
#  'xerostomia',
#  'control of menstrual periods',
#  'skin enema',
#  'herd (gastroesophogeal reflux disease)',
#  'add inattentive, delayed sleep phase syndrome',
#  'panic disorder',
#  'severe heartburn',
#  'asthma flares',
#  "hashimoto's choroiditis",
#  "beset's disease",
#  'chronic pain from disk hernia in cervical spine',
#  'angina',
#  'metallic syndrome x',
#  'bronchitis',
#  'uterine fibroids',
#  'plantar faciatis',
#  'depression; intrusion suicidal impulses',
#  'sore throat',
#  'sedition dentist for dental plants',
#  'hypercalcemia',
#  'tympanostomy tube placement surgery',
#  'thyreoid',
#  'plugged up nose related to seasonal galleries',
#  'mucus in stool',
#  'dermatitis',
#  'pinched nerves',
#  'inflammation at the femoral nerve',
#  'ear pain on same',
#  'trial fibrillation',
#  'stomach pain',
#  'asthma, galleries',
#  'blood clot as a cause of early stage miscarriage',
#  'high chloresteral',
#  'gestational diabetes',
#  'diet',
#  '2',
#  'll cholestrol',
#  'deep gum pockets',
#  'dietary supplementation',
#  'hair loss',
#  'vaginal bacteria',
#  'ankylosing spondylitis',
#  'high c',
#  'herpes foster, prophylaxis',
#  'allergic reaction on face to a cosmetic',
#  'hot flashes',
#  'pigmentation',
#  'bacteria',
#  'gastroenteritis',
#  'auditory processing disorder',
#  'alopecia',
#  'airplane flight anxiety',
#  'traumatic brain injury',
#  'prophylaxis after oral surgery',
#  'urge incontinence',
#  'anna',
#  'burns, external',
#  'transient ischaemic attack',
#  'adrenocortical insufficiency',
#  'structure infection',
#  'eustachian tube pain',
#  'leg pain from compressed spinal cord',
#  'lympho',
#  'rosacia',
#  'galleries, sinus congestion',
#  'reduce cholestrol',
#  'expectation',
#  "hypothyriodism--hashimoto's choroiditis",
#  'hypoglycemia',
#  'vaginal least infection',
#  'oral surgery; extraction, plants',
#  'campylobacter gastroenteritis',
#  'secondary hyperparathyroidism',
#  'eve',
#  'st',
#  'lower back pain',
#  'm.r.s.a.',
#  'cold sore on side of face',
#  'ciliary cirrhosis',
#  'auto accident, severe whiplash',
#  'prevent osteoporosis',
#  'large pores blockhead around nose & cheeks',
#  'sleep',
#  'osteopenia associated with menopause',
#  'excess stomach acid.',
#  'sleep disorder',
#  'pre cancer cells',
#  'severe non-allergic bronchitis',
#  'hyperthyroid - graves disease',
#  'labor pain',
#  'hyperpigmentation, photoaging, mild hormonal acne',
#  'beginning of osteoporosis of the hip',
#  'allergic reactions',
#  'neck & arm muscle spasms',
#  'anaplastic astrocytoma',
#  'severe peritoneal disease',
#  'very high cholestrol level 9.1',
#  'bipolar disorder, hypomania.',
#  'cystic vomiting syndrome',
#  'photoaging of the skin',
#  'giant cell arteritis',
#  'depression, anxiety & pain',
#  'bipolar 2',
#  'mrs',
#  'hypopituitarism',
#  'neurotic depression',
#  'caries',
#  'male pattern boldness',
#  'wrinkles,uneven skin tone,large pores',
#  'high cholestrol level',
#  'social anxiety disorder',
#  'multiple myeloma',
#  'seizure prevention',
#  'birth control, acne control',
#  'white spots on facial skin',
#  'anxiety, panic disorder',
#  'neuropathic pain',
#  'arrhythmia',
#  'bladder spasm',
#  'male andropause',
#  'migrate prevention',
#  'depression-anxiety',
#  'pus',
#  'malasha, uneven skin tone, occasionally pimples',
#  "hashimoto's hypothyroidism",
#  'verbal supplementation',
#  'menopausal symptoms',
#  'birthcontrol',
#  'surgical prophylaxis',
#  'menopause symptoms',
#  'post tooth extraction',
#  'recurrent depression',
#  't pay with cyclobenzaprine (cyclobenzaprine)',
#  'subungual haematoma',
#  'pain - chronic panceatitis',
#  'bladder pressure',
#  'hair lose',
#  'diverticulitis',
#  'ileocecal valve syndrome',
#  'heratburn',
#  'esophogeal structures',
#  'tuberculosis',
#  'minor insomnia',
#  'post surgical pain',
#  'menopause problems',
#  'anal fissure',
#  'multiple sclerosis',
#  'acute',
#  'post trauma depression',
#  'chronic myofascial pain',
#  'euvolemic hyponatremia',
#  'rhematory arthritis',
#  'insomnia, migraines',
#  'back',
#  'herniated disc',
#  'ulcerative cholitis',
#  'cerebral oedema',
#  'ear wax impaction',
#  'myeloproliferative disorders',
#  'anthrax',
#  'pertussis',
#  'suicidal feelings',
#  'schism-effective disorder',
#  'stomach bacteria',
#  'primary ovarian failure',
#  'transverse myelitis',
#  'cutaneous candidiasis',
#  'herpes simple',
#  'bipolar',
#  'poor sleep with frequent wakefulness',
#  'obesity',
#  'mastitis, nausea, fullness',
#  'hyperlipoproteinemia type iii, elevated ll',
#  'rapid heart rate',
#  'severe nodular acne',
#  'bipolar disorder 2',
#  'infection',
#  'pregnancy',
#  'linear isa disease',
#  'contraction pill',
#  'dysthymia',
#  'post menapausal osteopenia',
#  'reverse the insomnia meditation',
#  "can't sleep",
#  'severe anxiety',
#  'cholera',
#  'spinal injury',
#  'daytime sleepiness',
#  'facial hair',
#  'methicillin-resistant staphylococcus aureus infection',
#  'pain after minor surgery',
#  'st clamydia',
#  'attention deficit disorder',
#  'ear infection',
#  'chronic headache',
#  'infection from grazing an ankle on coral',
#  'perimenopause',
#  'hypothyriod',
#  'potato cuff tear',
#  'head injury',
#  'hot flashes, unable to sleep',
#  'heavy periods',
#  'birth control, menstrual cramps',
#  'chronic cold sores',
#  'tachacarrdia rapid heartfelt',
#  'pulmonary oedema',
#  'alcohol abuse',
#  'cutaneous lavra migrate',
#  'hyperlipoproteinemia type iii, elevated beta-all  ill',
#  'sinus infection with smell nasal discharge',
#  'acid reflux, herd',
#  'tic (mycophenolic acid)',
#  'nervous but yet confident',
#  'emergency contraction',
#  'sinus infection, bronchitis',
#  'skin disinfection, preoperative',
#  'organ transplant, rejection prophylaxis',
#  'chronic tension headache',
#  'cerebrovascular insufficiency',
#  'wakefulness -- difficulty falling back asleep',
#  'loose weight',
#  'renal tubular acidosis',
#  'hypoestrogenism',
#  'blood pressure',
#  'bacterial growth',
#  'bordering personality disorder, i polar',
#  'personal dermatitis',
#  'hepatocellular carcinoma',
#  'period cramps',
#  'migrate + birth control',
#  'toe-nail fungus',
#  'operative bladder',
#  'seasonal clergy',
#  'endometrial hyperplasia, prophylaxis',
#  'renal transplant',
#  'coccidioidomycosis',
#  'postoperative pain',
#  'facial',
#  'cholestrol levels',
#  'anxiety attacks',
#  'dyspepsia',
#  'heart burn',
#  'mycotic episode',
#  'autoimmune keratitis',
#  'add, inattentive type',
#  'prevention of diabetes',
#  'wound cleansing',
#  'manscaping pain',
#  "addison's disease",
#  'water retention',
#  'hypertension (high blood pressure)',
#  'prostatitis',
#  'prolactin inhibit',
#  'joint pain',
#  'nonoccupational exposure',
#  'hypercholestremia',
#  'tonsillitis, sinusitis also bad tooth ache.',
#  'dysthymia ( chronic, low grade depression )',
#  'granuloma annular',
#  'reassuring mastitis.',
#  'singles breakup',
#  'facial herpes simple',
#  'skin texture changes due to rosacea',
#  'hyhpothyroidism',
#  'add management',
#  'pre-surgery',
#  'post-cholecystectomy diarrhoea',
#  'ulcerative parotitis',
#  'shoulder & neck pain',
#  "baker's cysts behind both knees",
#  'dry eye',
#  'menopause, memory loss, night sweats, low livid',
#  'bronchial infection',
#  'low back pain, radiating to left leg',
#  'grow lashes',
#  'prevention of atherothrombotic events',
#  'menorrhagia',
#  'originally depression, later for chronic pain',
#  'i-polar 2',
#  'osteoporosis',
#  'skin and, sun damage',
#  'laryngopharyngeal reflux',
#  'fever blisters',
#  'severe accessed tooth',
#  'periodontal disease',
#  'have not stop bleeding',
#  'fungus',
#  'essential tremor',
#  'mild but resistant acne',
#  'no more monthly periods',
#  'hypercholesterolemia',
#  'lashes',
#  'stomach ulcers',
#  'chlamydia infection',
#  'pancreatitis',
#  'stomach acid',
#  'male pattern gladness',
#  'originally brain lesions then lower cholestrol',
#  'severe dry eyes',
#  'chronic eosinophilia leukaemia',
#  'sinusitis',
#  'leg blood clot, dot',
#  'spare thin eyelashes',
#  'ovarian cancer',
#  'anxiety, panic attack',
#  'back pain; restlessness',
#  'supposed add',
#  'panic attacks, depression',
#  'age spots on hand',
#  'glioblastoma multiforme',
#  "traveler's diarrhoea",
#  'raging skin, few break-out, hyperpigmentation',
#  'prophetic heart valves, mechanical valves - thrombosis prophylaxis',
#  'liver magnetic remove imagine',
#  'thyreoid suppression test',
#  'fun',
#  'seizure, hip, cholestrol',
#  'various type pain',
#  'root canal pain',
#  'i was in a risk group - frontline pharmacist',
#  'cardiomyopathy',
#  'clinical depression',
#  'depression, its',
#  'macular degeneration',
#  'st prophylaxis',
#  "paget's disease",
#  'irritated',
#  'inflammation of throat during bacteria bronchitis',
#  'swelling',
#  'premenstrual dysphoric disorder',
#  'hot',
#  'restless leg syndrome',
#  'chronic "typical" depression',
#  'epididymitis, sexually transmitted',
#  'soft tissue sarcoma',
#  'bleeding disorder',
#  'muscle strain',
#  'psoraitic arthritis',
#  'post shoulder surgery pain',
#  'diabetes insidious',
#  'bone density tests showed early osteo.',
#  'asthma, maintece',
#  'hives',
#  'sciatic nerve pain',
#  'mood disorder',
#  'i irritation',
#  'musculoskeletal pain; nerve pain',
#  'harmony replacement therapy',
#  'teeth extraction',
#  'chronic retinitis',
#  'dance anxiety',
#  'anaesthesia',
#  'cosmetic longer lashes',
#  'wrinkles',
#  'anxiety,insomnia',
#  'judging disk in neck',
#  'raging skin on face',
#  'broken ribs',
#  'actor ix deficiency',
#  'reaction with benzol peroxide',
#  'spinal nerve compression pain',
#  'haemophilia a',
#  'keratitis b',
#  'deep neck infection',
#  'under active thyreoid',
#  'over eating, reduce weight gain',
#  'drug addition',
#  'small bowel or pancreatic fistula',
#  'jet law',
#  'haemophilia b',
#  'for allergic condition',
#  'sinus problems',
#  'progesterone balance',
#  'heavy senses',
#  'somatoform pain disorder',
#  'dry eye disease',
#  'low thyreoid levels',
#  'dermatophytosis',
#  'all surgery',
#  'pemphigus',
#  'bronchitis infection',
#  'cat bite infection',
#  'cholestrol slightly elevated',
#  'i got my toothpulled',
#  'heavy period',
#  'weak bladder wet bed',
#  'all over',
#  'hot hysterectomy',
#  'anorexia',
#  'endoscopy or radiology premeditation',
#  'pain from pinched nerve',
#  'tuberculosis, active',
#  'blockhead,large pores,sun damage',
#  'state infection',
#  'fly symptoms',
#  'insomnia, headache',
#  'human papillomavirus prophylaxis',
#  'post surgery',
#  'clergy to trauma to the face.',
#  'pain control',
#  'accessed tooth',
#  'being stressed',
#  'depression & anxiety',
#  'gonorrhoea',
#  'psychosomatic disorder',
#  'mild depression',
#  'broken collarbones',
#  'cervical disk degeneration',
#  'oral infection',
#  'low energy',
#  'gender dysphoria',
#  'depression anxiety',
#  'sore throat with a low grade fever',
#  'balanitis',
#  'nerve damage, 1 nerve near mouth during surgery',
#  'restful sleep, narcolepsy?',
#  'babesiosis',
#  'sleep disorder, insomnia',
#  'pimples',
#  'hyperpigmentation',
#  'old',
#  'degenerative disc disorder, spinal stenosis ll-s',
#  'pulmonary embolism',
#  'pruritus',
#  'swine fly like illness in a anaemic',
#  'nausea (phosphorated carbohydrates solution)',
#  'mood stablizer for bipolar disorder',
#  'sinus infections',
#  'skin spots',
#  'peripheral pain arms',
#  'androgenetic alopecia',
#  'prevent pregnancy',
#  'illiotibital tibial syndrome',
#  'pain',
#  'cold',
#  'a typical migraines',
#  'eostrogen-positive breast cancer',
#  'back injury',
#  'major depression disorder',
#  'nasal carriage of staphylococcus aureus',
#  'uneven skin tone',
#  'greater depression',
#  'heart problem',
#  'tuberculosis, prophylaxis',
#  'oral surgery',
#  'fybromyalgia',
#  'wrinkles premature raging',
#  'glandular fever',
#  'mixed connective tissue disease',
#  'rhinorrhea',
#  'diabetic kidney disease',
#  'seizure-st',
#  'paragonimus westermani, lung luke',
#  'deep vein thrombosis, recurrent event',
#  'pre-garrett (erosion of the oesophagus)',
#  'mouth. between the brow',
#  'anxiety, hopelessness',
#  'ophthalmic surgery',
#  'agoraphobia, panic disorder',
#  'trichomoniasis',
#  'hypercholesteremia',
#  'peripheral neuropathic',
#  'sycosis',
#  'histoplasmosis',
#  'post dental work',
#  'percutaneous coronary intervention',
#  'menopausal symptoms - hot flashes, sleep disturbance',
#  'mycoplasma pneumonia',
#  'diagnostic bronchograms',
#  'heart attack',
#  'ms-related fatigue',
#  'focus',
#  'allergic reaction',
#  'pediatric growth harmony deficiency',
#  'sun damage removal',
#  'step throat',
#  'restless sleep',
#  'simple laceration',
#  'facial lines',
#  'myofacial pain',
#  'acute sinusitis',
#  'overnight, self confidence',
#  'wanted to drop about 30 les',
#  'strabismus',
#  'hypothroidism',
#  'raging skin, wrinkles, say',
#  'ulcer',
#  'herd',
#  "atkinson's disease",
#  'possible ulcer',
#  'recurrent pseudomonas chest infection',
#  'anxiety from a reaction',
#  'insomnia,',
#  'severe galleries',
#  'hypokalemic periodic paralysis',
#  'muscle stiffness',
#  'i kept getting pregnant. no more stairs.... please',
#  ...}

# %%
# Get dataframe of all drug-condition pairs
drug = []
condition = []

# Iterate through each row to extract each drug and its list of conditions
for row in range(3723):
    condition_list = literal_eval(str(df_combined['reduced_conditions'][row]))
    
    # Iterate through the list of conditions to keep track of each drug-condition pair for the current row
    for cond in condition_list:
        drug.append(df_combined['drugNameReduced'][row])
        condition.append(cond)

# Add list of drugs and their corresponding conditions to a DataFrame
df_treatment = pd.DataFrame(list(zip(drug, condition)),columns =['drug', 'condition'])

# Save as csv to load as Drug-Condition edges in Neo4J
df_treatment.to_csv('/csv/treatment.csv')

# %% [markdown]
# ### Combining with GAD dataset

# %%
# Load our list of unique conditions
conditions = pd.read_csv("/csv/conditions.csv", index_col=0)
conditions
# Out:
#                                        condition
# 0     chronic idiopathic urticaria with neuritis
# 1                            extreme hot flashes
# 2                          red spot on the cheek
# 3                                      menopause
# 4                               diabetes, type 2
# ...                                          ...
# 2218             inability to fall asleep easily
# 2219                                    dandruff
# 2220                     acute coronary syndrome
# 2221         adult moderate harmony related acne
# 2222              anti mad receptor encephalitis
#
# [2223 rows x 1 columns]

# %%
# Load GAD dataset
gad = pd.read_csv("Data/gad.csv")
# Replace the 'hypertension' phenotype with 'high blood pressure' to better match our drug-condition dataset
gad['phenotype'] = gad['phenotype'].replace('hypertension', 'high blood pressure')
# Reduce phenotypes by removing special characters and converting to lowercase
gad['phenotype_reduced'] = gad['phenotype'].apply(lambda x: re.sub('[^A-Za-z0-9]', ' ', str(x).lower()))
# Drop unecessary columns
gad = gad.drop(['reference', 'pubmed_id', 'year', 'population', 'gad_id'], axis=1)
# Only keep the rows that do have a phenotype-gene association
gad = gad[gad['association'] == 'Y']
# Drop duplicate rows
gad = gad.drop_duplicates()
# Replace NaN values with zeros
gad['chromosome'] = gad['chromosome'].fillna(0)
gad['chromosome_band'] = gad['chromosome_band'].fillna(0)
gad['gene_name'] = gad['gene_name'].fillna(0)

gad
# Out:
#       association                   phenotype    disease_class chromosome  \
# 2               Y         Parkinson's Disease     NEUROLOGICAL         12
# 9               Y         Alzheimer`s disease     NEUROLOGICAL         12
# 15              Y            normal variation  NORMALVARIATION         12
# 16              Y        rheumatoid arthritis           IMMUNE         12
# 20              Y  argyrophilic grain disease     NEUROLOGICAL         12
# ...           ...                         ...              ...        ...
# 39904           Y               asthma eczema           IMMUNE          1
# 39905           Y                      eczema           IMMUNE          1
# 39907           Y           venous thrombosis   CARDIOVASCULAR          4
# 39908           Y           venous thrombosis   CARDIOVASCULAR          1
# 39909           Y           venous thrombosis   CARDIOVASCULAR         19
#
#       chromosome_band  dna_start    dna_end      gene  \
# 2       12p13.3-p12.3    9111570    9159825       A2M
# 9       12p13.3-p12.3    9111570    9159825       A2M
# 15      12p13.3-p12.3    9111570    9159825       A2M
# 16      12p13.3-p12.3    9111570    9159825       A2M
# 20      12p13.3-p12.3    9111570    9159825       A2M
# ...               ...        ...        ...       ...
# 39904            1q21  150541275  150564303       FLG
# 39905            1q21  150541275  150564303       FLG
# 39907          4q35.2  187487823  187509760    CYP4V2
# 39908      1q23-q25.1  172139564  172153096  SERPINC1
# 39909         19q13.4          0          0       GP6
#
#                                                gene_name  \
# 2                                  Alpha-2-macroglobulin
# 9                                  Alpha-2-macroglobulin
# 15                                 Alpha-2-macroglobulin
# 16                                 Alpha-2-macroglobulin
# 20                                 Alpha-2-macroglobulin
# ...                                                  ...
# 39904                                          Filaggrin
# 39905                                          Filaggrin
# 39907  cytochrome P450, family 4, subfamily V, polype...
# 39908  serpin peptidase inhibitor, clade C (antithrom...
# 39909                         glycoprotein VI (platelet)
#
#                 phenotype_reduced
# 2             parkinson s disease
# 9             alzheimer s disease
# 15               normal variation
# 16           rheumatoid arthritis
# 20     argyrophilic grain disease
# ...                           ...
# 39904               asthma eczema
# 39905                      eczema
# 39907           venous thrombosis
# 39908           venous thrombosis
# 39909           venous thrombosis
#
# [8877 rows x 10 columns]

# %%
# Inner join of the conditions and gad dataframes, matching on condition/phenotype names
condition_gad = conditions.merge(gad, left_on='condition', right_on='phenotype_reduced', how='inner')

# Save as csv to load as Condition-Gene edges in Neo4J
condition_gad.to_csv('/csv/gene_interactions.csv')

# %%
# Get dataframe of unique genes

# Drop duplicate rows
gad_unique = condition_gad.drop_duplicates(['chromosome','chromosome_band', 'dna_start', 
                                            'dna_end', 'gene'],keep= 'last')

# Only keep the chromosome, chromosome_band, dna_start, dna_end, gene, and gene_name columns
gad_unique = gad_unique[['chromosome','chromosome_band', 'dna_start', 
                                            'dna_end', 'gene', 'gene_name']]

# Save as csv to lead as Gene nodes in Neo4J
gad_unique.to_csv('/csv/genes.csv')
